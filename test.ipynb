# %%
import torch

# %%
import matplotlib.pylab as plt
# %matplotlib inline

data = []
with open('reward.txt', 'r') as f:
    data = f.readlines()
idata = [float(d) for d in data]

w_data = []
window = 2000
for i in range(0, len(idata)//window):
    d = idata[i*window:(i+1)*window]
    w_data.append(sum(d) / len(d))

plt.plot(w_data)
